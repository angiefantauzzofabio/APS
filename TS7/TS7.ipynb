# %% [markdown]
# # TS7: Transformada Z y Respuesta en frecuencia
# ### Autoras: Angelina Fantauzzo Fabio y Noelia Ferrari
#
# **Consigna**:
# Dado las siguientes ecuaciones en diferencias de los siguientes sistemas, que representan un filtro de media móvil:
#
# $$
# \text{a) } y(n)=x(n-3)+x(n-2)+x(n-1)+x(n)
# $$
#
# $$
# \text{b) } y(n)=x(n-4)+x(n-3)+x(n-2)+x(n-1)+x(n)
# $$
#
# $$
# \text{c) } y(n)=x(n)-x(n-1)
# $$
#
# $$
# \text{d) } y(n)=x(n)-x(n-2)
# $$
#
# Se pide:
#
# 1) Hallar $T(z)=\frac{Y(z)}{X(z)}$.
#
# 2) Calcular su respuesta en frecuencia de módulo y fase.
#
# 3) Simular y validar la respuesta en frecuencia de todos los sistemas con Numpy.

# %% [markdown]
# ## Introducción teórica

# %% [markdown]
# Un sistema discreto se describe en el dominio temporal mediante una ecuación en diferencias. Las ecuaciones dadas en este trabajo son de la forma:
# $$y(n) = \sum_{k=0}^{M} b_k x(n-k)$$
#
# Para analizar la estructura y estabilidad de un sistema, utilizamos la **Transformada Z**. Aplicar esta transformada a una ecuación en diferencias convierte las operaciones de convolución y retardo temporal en operaciones algebraicas en el plano complejo Z.
#
# La función de Transferencia $T(z)$ (o $H(z)$) se define como:
# $$T(z) = \frac{Y(z)}{X(z)}$$
#
# Una de las características importantes para el diseño de filtros es su **Respuesta en Frecuencia** $H(j\omega)$, que describe cómo el sistema modifica la amplitud y la fase de las diferentes componentes frecuenciales de una señal de entrada.
#
# Esta respuesta se obtiene evaluando la función de transferencia $T(z)$ sobre el círculo unitario en el plano Z, haciendo la sustitución:
# $$z = e^{j\omega}$$
# Donde $\omega$ es la frecuencia angular normalizada.
#
# La respuesta en frecuencia es un número complejo y se analiza en términos de:
# * **Módulo $|H(j\omega)|$ (Ganancia/Amplitud):** Indica la amplificación o atenuación que sufre cada frecuencia.
# * **Fase $\angle H(j\omega)$:** Indica el desplazamiento temporal (retardo) que experimenta cada frecuencia.

# %% [markdown]
# ### Ecuación A

# %% [markdown]
# $$
# \text{a) } y(n)=x(n-3)+x(n-2)+x(n-1)+x(n)
# $$

# %%
from IPython.display import Image
import os
Image(filename=os.path.join("Imagen1.jpeg"))

# %%
Image(filename=os.path.join("Imagen2.jpeg"))

# %%
Image(filename=os.path.join("Imagen3.jpeg"))

# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt


b = [1, 1, 1, 1]      # Coeficientes del numerador del filtro
a = [1]               # Coeficientes del denominador del filtro

w, h = signal.freqz(b, a, worN=1000)


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(w, np.abs(h))
plt.title("Módulo")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4), 
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("|T(e^{jω})|")
plt.grid()


plt.subplot(1, 2, 2)
plt.plot(w, np.angle(h))
plt.title("Fase")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4), 
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("∠T(e^{jω}) [rad]")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ecuación B

# %% [markdown]
# $$
# \text{b) } y(n)=x(n-4)+x(n-3)+x(n-2)+x(n-1)+x(n)
# $$

# %%
Image(filename=os.path.join("Imagen4.jpeg"))

# %%
b = [1, 1, 1, 1, 1]      # Coeficientes del numerador del filtro
a = [1]               # Coeficientes del denominador del filtro

w, h = signal.freqz(b, a, worN=1000)


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(w, np.abs(h))
plt.title("Módulo")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4), 
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("|T(e^{jω})|")
plt.grid()


plt.subplot(1, 2, 2)
plt.plot(w, np.angle(h))
plt.title("Fase")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4), 
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("∠T(e^{jω}) [rad]")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ecuación C

# %% [markdown]
# $$
# \text{c) } y(n)=x(n)-x(n-1)
# $$

# %%
Image(filename=os.path.join("Imagen5.png"))

# %%
Image(filename=os.path.join("Imagen6.png"))

# %%
b = [1, -1]   # Numerador
a = [1]       # Denominador

# Calcular la respuesta en frecuencia
w, h = signal.freqz(b, a, worN=1000)

# Gráficos
plt.figure(figsize=(12, 5))

# Módulo
plt.subplot(1, 2, 1)
plt.plot(w, np.abs(h))
plt.title("Módulo de T(e^{jω})")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4),
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("|T(e^{jω})|")
plt.grid()

# Fase
plt.subplot(1, 2, 2)
plt.plot(w, np.angle(h))
plt.title("Fase de T(e^{jω})")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4),
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("∠T(e^{jω}) [rad]")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ecuación D

# %% [markdown]
# $$
# \text{d) } y(n)=x(n)-x(n-2)
# $$

# %%
Image(filename=os.path.join("Imagen7.png"))

# %%
Image(filename=os.path.join("Imagen8.png"))

# %%
b = [1, 0, -1]   # Numerador
a = [1]          # Denominador
# Calcular la respuesta en frecuencia
w, h = signal.freqz(b, a, worN=1000)

# Gráficos
plt.figure(figsize=(12, 5))

# Módulo
plt.subplot(1, 2, 1)
plt.plot(w, np.abs(h))
plt.title("Módulo de T(e^{jω})")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4),
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("|T(e^{jω})|")
plt.grid()

# Fase
plt.subplot(1, 2, 2)
plt.plot(w, np.angle(h))
plt.title("Fase de T(e^{jω})")
plt.xticks(np.arange(0, np.pi + 0.01, np.pi / 4),
           [r'$0$', r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$'])
plt.xlabel("ω [rad/muestra]")
plt.ylabel("∠T(e^{jω}) [rad]")
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# A partir del análisis de las ecuaciones en diferencias, se comprobó que cada sistema representa un filtro FIR con distintas configuraciones de coeficientes, lo que determina su comportamiento en frecuencia. En los casos A y B se ve una clara atenuación de las componentes de alta frecuencia dandonos a entender de que se tratan de iun filtro pasabajos. En cambio, los sistemas de diferencia C y D se comportan como filtros pasaaltos, resaltando los cambios rápidos de la señal.
